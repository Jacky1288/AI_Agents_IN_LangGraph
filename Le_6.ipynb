# %% [markdown]
# # Lesson 6: Essay Writer

# %%
from dotenv import load_dotenv

_ = load_dotenv()

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated, List
import operator
from langgraph.checkpoint.memory import MemorySaver
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, AIMessage, ChatMessage

memory = MemorySaver()

# %%
class AgentState(TypedDict):
    task: str
    plan: str
    draft: str
    critique: str
    content: List[str]
    revision_number: int
    max_revisions: int

# %%
from langchain_openai import ChatOpenAI
model = ChatOpenAI(model="gpt-3.5-turbo", temperature=0)

# %%
PLAN_PROMPT = """You are an expert writer tasked with writing a high level outline of an essay. \
Write such an outline for the user provided topic. Give an outline of the essay along with any relevant notes \
or instructions for the sections."""

# %%
WRITER_PROMPT = """You are an essay assistant tasked with writing excellent 5-paragraph essays.\
Generate the best essay possible for the user's request and the initial outline. \
If the user provides critique, respond with a revised version of your previous attempts. \
Utilize all the information below as needed: 

------

{content}"""

# %%
REFLECTION_PROMPT = """You are a teacher grading an essay submission. \
Generate critique and recommendations for the user's submission. \
Provide detailed recommendations, including requests for length, depth, style, etc."""

# %%
RESEARCH_PLAN_PROMPT = """You are a researcher charged with providing information that can \
be used when writing the following essay. Generate a list of search queries that will gather \
any relevant information. Only generate 3 queries max."""

# %%
RESEARCH_CRITIQUE_PROMPT = """You are a researcher charged with providing information that can \
be used when making any requested revisions (as outlined below). \
Generate a list of search queries that will gather any relevant information. Only generate 3 queries max."""

# %%
from pydantic import BaseModel

class Queries(BaseModel):
    queries: List[str]

# %%
from tavily import TavilyClient
import os
tavily = TavilyClient(api_key=os.environ["TAVILY_API_KEY"])

# %%
def plan_node(state: AgentState):
    messages = [
        SystemMessage(content=PLAN_PROMPT), 
        HumanMessage(content=state['task'])
    ]
    response = model.invoke(messages)
    return {"plan": response.content}

# %%
def research_plan_node(state: AgentState):
    queries = model.with_structured_output(Queries).invoke([
        SystemMessage(content=RESEARCH_PLAN_PROMPT),
        HumanMessage(content=state['task'])
    ])
    content = state['content'] or []
    for q in queries.queries:
        response = tavily.search(query=q, max_results=2)
        for r in response['results']:
            text = r.get('content') or r.get('raw_content') or ''
            if text:
                content.append(text)
    return {"content": content}

# %%
def generation_node(state: AgentState):
    content = "\n\n".join(state['content'] or [])
    user_message = HumanMessage(
        content=f"{state['task']}\n\nHere is my plan:\n\n{state['plan']}")
    messages = [
        SystemMessage(
            content=WRITER_PROMPT.format(content=content)
        ),
        user_message
        ]
    response = model.invoke(messages)
    return {
        "draft": response.content, 
        "revision_number": state.get("revision_number", 1) + 1
    }

# %%
def reflection_node(state: AgentState):
    messages = [
        SystemMessage(content=REFLECTION_PROMPT), 
        HumanMessage(content=state['draft'])
    ]
    response = model.invoke(messages)
    return {"critique": response.content}

# %%
def research_critique_node(state: AgentState):
    queries = model.with_structured_output(Queries).invoke([
        SystemMessage(content=RESEARCH_CRITIQUE_PROMPT),
        HumanMessage(content=state['critique'])
    ])
    content = state['content'] or []
    for q in queries.queries:
        response = tavily.search(query=q, max_results=2)
        for r in response['results']:
            text = r.get('content') or r.get('raw_content') or ''
            if text:
                content.append(text)
    return {"content": content}

# %%
def should_continue(state):
    if state["revision_number"] > state["max_revisions"]:
        return END
    return "reflect"

# %%
builder = StateGraph(AgentState)

# %%
builder.add_node("planner", plan_node)
builder.add_node("generate", generation_node)
builder.add_node("reflect", reflection_node)
builder.add_node("research_plan", research_plan_node)
builder.add_node("research_critique", research_critique_node)

# %%
builder.set_entry_point("planner")

# %%
builder.add_conditional_edges(
    "generate", 
    should_continue, 
    {END: END, "reflect": "reflect"}
)

# %%
builder.add_edge("planner", "research_plan")
builder.add_edge("research_plan", "generate")

builder.add_edge("reflect", "research_critique")
builder.add_edge("research_critique", "generate")

# %%
graph = builder.compile(checkpointer=memory)

# %%
from IPython.display import Image

Image(graph.get_graph().draw_mermaid_png())

# %%
import inspect
print("=== research_plan_node source ===")
print(inspect.getsource(research_plan_node))
print("=== research_plan_node module ===")
print(research_plan_node.__module__)
print(research_plan_node.__code__.co_filename)
print(research_plan_node.__code__.co_firstlineno)
# Out:
# === research_plan_node source ===
# def research_plan_node(state: AgentState):
#     queries = model.with_structured_output(Queries).invoke([
#         SystemMessage(content=RESEARCH_PLAN_PROMPT),
#         HumanMessage(content=state['task'])
#     ])
#     content = state['content'] or []
#     for q in queries.queries:
#         response = tavily.search(query=q, max_results=2)
#         for r in response['results']:
#             text = r.get('content') or r.get('raw_content') or ''
#             if text:
#                 content.append(text)
#     return {"content": content}
#
# === research_plan_node module ===
# __main__
# /var/folders/yk/0_j8dnmn44l_4ypqsx_wz7xh0000gn/T/ipykernel_74974/2524938350.py
# 1

# %%
thread = {"configurable": {"thread_id": "1"}}
for s in graph.stream({
    'task': "what is the difference between langchain and langsmith",
    "max_revisions": 2,
    "revision_number": 1,
    "content": [],          # ← 加这一行
}, thread):
    print(s)
# Out:
# {'planner': {'plan': 'I. Introduction\n    A. Brief overview of Langchain and Langsmith\n    B. Thesis statement: Exploring the differences between Langchain and Langsmith\n\nII. Langchain\n    A. Definition and explanation\n    B. Key features and characteristics\n    C. Use cases and applications\n    D. Advantages and disadvantages\n\nIII. Langsmith\n    A. Definition and explanation\n    B. Key features and characteristics\n    C. Use cases and applications\n    D. Advantages and disadvantages\n\nIV. Comparison between Langchain and Langsmith\n    A. Differentiating factors\n    B. Similarities and overlaps\n    C. Which one to choose for specific scenarios\n\nV. Conclusion\n    A. Recap of main points\n    B. Final thoughts on the significance of understanding the differences between Langchain and Langsmith'}}
# /Users/taozh/Documents/agents/LangGraph/AI_Agents_IN_LangGraph/.venv/lib/python3.13/site-packages/langchain_openai/chat_models/base.py:2393: UserWarning: Cannot use method='json_schema' with model gpt-3.5-turbo since it doesn't support OpenAI's Structured Output API. You can see supported models here: https://platform.openai.com/docs/guides/structured-outputs#supported-models. To fix this warning, set `method='function_calling'. Overriding to method='function_calling'.
#   warnings.warn(
# {'research_plan': {'content': ['**TL;DR:**\xa0*LangChain and LangSmith play different roles in your LLM dev stack. LangChain is a framework for building applications, while LangSmith is a platform for debugging, evaluating, deploying, and monitoring them.*. Teams building with models such as OpenAI’s GPT-5, Anthropic’s Claude models, or open-source alternatives need tools that simplify both development and monitoring. LangChain became a leading framework for orchestrating LLM workflows, while LangSmith followed to fill important gaps in debugging, evaluation, and production readiness. Let’s look at what each framework and platform does, how they differ, and when to use one or both. LangChain\xa0is an open-source framework for building agents and LLM-powered applications. The framework lets you chain together models, embeddings, vector stores, and tools, simplifying the development of complex LLM applications. ### When to Use LangChain? You can use it with LangChain, LangGraph, or any other setup, including custom code that calls LLM APIs directly. ### When to Use LangSmith. ## When to Use LangChain or LangSmith.', 'If you’re responsible for ensuring your AI models work in production, or you need to frequently debug and monitor your pipelines, Langsmith is your go-to tool. In short, while **Langchain** excels at managing and scaling model workflows, **Langsmith** is designed for those times when you need deep visibility and control over large, complex AI systems in production. But if you’re managing a **complex AI pipeline** with multiple models that need debugging and orchestrating, Langsmith’s capabilities become essential. However, if you’re dealing with **large-scale production environments** that require deep monitoring, performance tuning, and orchestration across various models and platforms, Langsmith’s more advanced architecture will handle your needs better. If you’re debugging complex AI models or managing large-scale workflows with multiple moving parts, **Langsmith’s advanced debugging and orchestration features** will be indispensable. Choosing between **Langchain** and **Langsmith** boils down to understanding your project’s complexity, scalability needs, and the level of control you want over your AI models.', 'LangChain is an open source framework with a prebuilt agent architecture and integrations for any model or tool—so you can build agents that adapt as fast as the ecosystem evolves. Build completely custom agents and applications powered by LLMs in under 10 lines of code, with integrations for OpenAI, Anthropic, Google, and more. LangChain provides a prebuilt agent architecture and model integrations to help you get started quickly and seamlessly incorporate LLMs into your agents and applications. Deep Agents are built on LangChain agents which you can also use LangChain directly.Use LangGraph, our low-level orchestration framework, for advanced needs combining deterministic and agentic workflows.Use LangSmith to trace, debug, and evaluate agents built with any of these frameworks. See the Installation instructions and Quickstart guide to get started building your own agents and applications with LangChain. LangChain’s agent abstraction is designed to be easy to get started with, letting you build a simple agent in under 10 lines of code.', 'LangChain is an open source framework for building applications based on large language models (LLMs). LLMs are large deep-learning models pre-trained on large amounts of data that can generate responses to user queries—for example, answering questions or creating images from text-based prompts. LangChain provides tools and abstractions to improve the customization, accuracy, and relevancy of the information the models generate. For example, developers can use LangChain components to build new prompt chains or customize existing templates. To do that, machine learning engineers must integrate the LLM with the organization’s internal data sources and apply *prompt engin ...
# {'generate': {'draft': "**Essay: Exploring the Differences Between LangChain and LangSmith**\n\nI. **Introduction**\nLangChain and LangSmith are two essential components in the development and deployment of applications powered by large language models (LLMs). While both frameworks play crucial roles in the LLM development stack, they serve distinct purposes. This essay aims to delve into the disparities between LangChain and LangSmith to provide a comprehensive understanding of their functionalities.\n\nII. **LangChain**\nLangChain is an open-source framework tailored for building agents and LLM-powered applications. It simplifies the development of intricate LLM applications by chaining together models, embeddings, vector stores, and tools. The framework offers flexibility, allowing integration with various setups, including custom code that directly calls LLM APIs. LangChain's advantages lie in its ease of use, adaptability, and the ability to build custom agents swiftly. However, it may have limitations in scenarios requiring deep monitoring and debugging capabilities.\n\nIII. **LangSmith**\nIn contrast, LangSmith serves as a platform designed for debugging, evaluating, deploying, and monitoring LLM applications. It excels in providing deep visibility and control over complex AI systems in production. LangSmith is indispensable for managing large-scale workflows, offering advanced debugging and orchestration features. Its architecture is tailored for intricate AI pipelines that demand meticulous monitoring, performance tuning, and orchestration across multiple models and platforms.\n\nIV. **Comparison Between LangChain and LangSmith**\nWhen comparing LangChain and LangSmith, the key differentiating factor lies in their primary functions. LangChain focuses on simplifying the development of LLM applications, while LangSmith specializes in providing tools for debugging, monitoring, and deploying these applications. While LangChain is ideal for managing and scaling model workflows, LangSmith is crucial for ensuring the smooth operation of complex AI systems in production environments. The choice between LangChain and LangSmith depends on the project's complexity, scalability needs, and the level of control required over the AI models.\n\nV. **Conclusion**\nIn conclusion, understanding the disparities between LangChain and LangSmith is vital for effectively leveraging these frameworks in LLM development. LangChain streamlines the application-building process, while LangSmith enhances the debugging and monitoring aspects. By comprehending the unique features and use cases of LangChain and LangSmith, developers can make informed decisions on which framework best suits their specific requirements, ultimately leading to more efficient and successful LLM-powered applications.", 'revision_number': 2}}
# {'reflect': {'critique': "**Critique:**\n- The essay provides a clear introduction, explanation of LangChain and LangSmith, a comparison between the two, and a conclusion. \n- The content is informative and well-structured, making it easy to understand the key differences between LangChain and LangSmith.\n- The essay effectively highlights the primary functions and advantages of each framework.\n\n**Recommendations:**\n1. **Depth and Detail:** While the essay provides a good overview of LangChain and LangSmith, consider adding more depth to each section. Provide specific examples, case studies, or real-world applications where each framework excels. This will help readers grasp the practical implications of using LangChain and LangSmith.\n\n2. **Technical Details:** Include more technical details about the frameworks, such as the specific tools, features, and functionalities they offer. This will enhance the reader's understanding of how LangChain and LangSmith work and what sets them apart from each other.\n\n3. **Case Studies:** Incorporate case studies or examples of companies or projects that have successfully utilized LangChain and LangSmith. This will add credibility to your analysis and demonstrate the real-world impact of these frameworks.\n\n4. **Pros and Cons:** While you briefly mentioned some advantages and limitations of LangChain and LangSmith, consider expanding on this aspect. Provide a more comprehensive list of pros and cons for each framework to give readers a balanced view of their capabilities.\n\n5. **Recommendations:** Conclude the essay with specific recommendations for when to use LangChain versus LangSmith based on project requirements, scalability needs, and complexity. This will help readers make informed decisions when choosing between the two frameworks.\n\n6. **Length:** Consider expanding the essay to provide more in-depth analysis and examples. Aim for around 1000-1500 words to cover the topic comprehensively.\n\nBy incorporating these recommendations, you can enhance the depth and clarity of your essay, providing readers with a more thorough understanding of the differences between LangChain and LangSmith."}}
# {'research_critique': {'content': ['**TL;DR:**\xa0*LangChain and LangSmith play different roles in your LLM dev stack. LangChain is a framework for building applications, while LangSmith is a platform for debugging, evaluating, deploying, and monitoring them.*. Teams building with models such as OpenAI’s GPT-5, Anthropic’s Claude models, or open-source alternatives need tools that simplify both development and monitoring. LangChain became a leading framework for orchestrating LLM workflows, while LangSmith followed to fill important gaps in debugging, evaluation, and production readiness. Let’s look at what each framework and platform does, how they differ, and when to use one or both. LangChain\xa0is an open-source framework for building agents and LLM-powered applications. The framework lets you chain together models, embeddings, vector stores, and tools, simplifying the development of complex LLM applications. ### When to Use LangChain? You can use it with LangChain, LangGraph, or any other setup, including custom code that calls LLM APIs directly. ### When to Use LangSmith. ## When to Use LangChain or LangSmith.', 'If you’re responsible for ensuring your AI models work in production, or you need to frequently debug and monitor your pipelines, Langsmith is your go-to tool. In short, while **Langchain** excels at managing and scaling model workflows, **Langsmith** is designed for those times when you need deep visibility and control over large, complex AI systems in production. But if you’re managing a **complex AI pipeline** with multiple models that need debugging and orchestrating, Langsmith’s capabilities become essential. However, if you’re dealing with **large-scale production environments** that require deep monitoring, performance tuning, and orchestration across various models and platforms, Langsmith’s more advanced architecture will handle your needs better. If you’re debugging complex AI models or managing large-scale workflows with multiple moving parts, **Langsmith’s advanced debugging and orchestration features** will be indispensable. Choosing between **Langchain** and **Langsmith** boils down to understanding your project’s complexity, scalability needs, and the level of control you want over your AI models.', 'LangChain is an open source framework with a prebuilt agent architecture and integrations for any model or tool—so you can build agents that adapt as fast as the ecosystem evolves. Build completely custom agents and applications powered by LLMs in under 10 lines of code, with integrations for OpenAI, Anthropic, Google, and more. LangChain provides a prebuilt agent architecture and model integrations to help you get started quickly and seamlessly incorporate LLMs into your agents and applications. Deep Agents are built on LangChain agents which you can also use LangChain directly.Use LangGraph, our low-level orchestration framework, for advanced needs combining deterministic and agentic workflows.Use LangSmith to trace, debug, and evaluate agents built with any of these frameworks. See the Installation instructions and Quickstart guide to get started building your own agents and applications with LangChain. LangChain’s agent abstraction is designed to be easy to get started with, letting you build a simple agent in under 10 lines of code.', 'LangChain is an open source framework for building applications based on large language models (LLMs). LLMs are large deep-learning models pre-trained on large amounts of data that can generate responses to user queries—for example, answering questions or creating images from text-based prompts. LangChain provides tools and abstractions to improve the customization, accuracy, and relevancy of the information the models generate. For example, developers can use LangChain components to build new prompt chains or customize existing templates. To do that, machine learning engineers must integrate the LLM with the organization’s internal data sources and apply *prompt e ...
# {'generate': {'draft': "**Title: Understanding the Differences Between LangChain and LangSmith**\n\nI. Introduction\nLangChain and LangSmith play crucial roles in the development and management of applications powered by large language models (LLMs). While LangChain focuses on building applications, LangSmith is designed for debugging, evaluating, deploying, and monitoring them. This essay delves into the disparities between LangChain and LangSmith to aid in making informed decisions.\n\nII. LangChain\nLangChain is an open-source framework tailored for constructing agents and LLM-powered applications. It simplifies the development of intricate LLM applications by chaining together models, embeddings, vector stores, and tools. LangChain offers flexibility, ease of use, and integrations with various models and tools, making it ideal for prototyping and integrating multiple data sources.\n\nIII. LangSmith\nIn contrast, LangSmith serves as a platform for enhancing the development of natural language processing (NLP) applications. It builds upon LangChain's capabilities to streamline the creation of complex NLP workflows. LangSmith provides tools for managing, deploying, and scaling NLP applications efficiently, making it indispensable for debugging and monitoring large-scale AI systems in production.\n\nIV. Comparison between LangChain and LangSmith\nLangChain excels in managing and scaling model workflows, while LangSmith focuses on providing deep visibility and control over complex AI systems. LangSmith's advanced debugging and orchestration features make it essential for managing intricate AI pipelines, whereas LangChain is more suitable for projects requiring rapid prototyping and integration of external tools.\n\nV. Conclusion\nUnderstanding the distinctions between LangChain and LangSmith is crucial for selecting the right tool for specific project requirements. While LangChain is ideal for building and prototyping LLM applications, LangSmith shines in debugging, evaluating, and monitoring AI systems in production. By comprehending the unique strengths of each framework, developers can leverage them effectively to create powerful and efficient AI applications.", 'revision_number': 3}}

# %% [markdown]
# ## Essay Writer Interface

# %%
import warnings
warnings.filterwarnings("ignore")

from helper import ewriter, writer_gui

# %%
MultiAgent = ewriter()
app = writer_gui(MultiAgent.graph)
app.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
